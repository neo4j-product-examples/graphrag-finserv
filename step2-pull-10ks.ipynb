# %% [markdown]
# # Pull 10k Filings
# Based off Sample mappings

# %%
# %%capture
# %pip install python-dotenv pandas tqdm lxml

# %%
import pandas as pd
from dotenv import load_dotenv
import os

pd.set_option('display.width', 0)
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# ## Get and Save 10k URLs

# %%
map_df = pd.read_csv('cik-cusip-sample-map.csv')
map_df.cik = map_df.cik.astype(int)
map_df.sort_values(by='cusip6')
map_df
# Out:
#       cusip6      cik  \
# 0     001055     4977
# 1     001084  1100441
# 2     001228  1514281
# 3     00123Q  1423689
# 4     00130H   874761
# ...      ...      ...
# 4643  Y81669  1328919
# 4644  Y8564W   911971
# 4645  Y8565N  1419945
# 4646  Y8897Y  1296484
# 4647  Y95308  1631574
#
#                                                                         name  \
# 0                                                              {'AFLAC INC'}
# 1                                                              {'AGCO CORP'}
# 2                                           {'AG MORTGAGE INVESTMENT TRUST'}
# 3                                {'AGNC INVT CORP', 'AGNC Investment Corp.'}
# 4                                                               {'AES CORP'}
# ...                                                                      ...
# 4643                                                      {'STEALTHGAS INC'}
# 4644                                    {'TEEKAY CORPORATION', 'Teekay Inc'}
# 4645  {'TEEKAY TANKERS LTD', 'Teekay Tankers', 'TEEKAY TANKERS LTD-CLASS A'}
# 4646                                                       {'TOP SHIPS INC'}
# 4647                                              {'WAVE LIFE SCIENCES LTD'}
#
#                                                                   cusip
# 0                  {'001055102', '001055952', '000105510', '001055902'}
# 1                               {'001084952', '001084902', '001084102'}
# 2                                                         {'001228501'}
# 3                  {'00123q104', '00123Q104', '00123Q954', '00123Q904'}
# 4                  {'00130H905', '00130H955', '00130H105', '00130h105'}
# ...                                                                 ...
# 4643                                                      {'Y81669106'}
# 4644               {'Y8564W103', 'y8564w103', 'Y8564W903', 'Y8564W953'}
# 4645  {'Y8565N900', 'y8565n102', 'Y8565N300', 'y8565n300', 'Y8565N950'}
# 4646                                                      {'y8897y198'}
# 4647                                                      {'Y95308105'}
#
# [4648 rows x 4 columns]

# %%
import json
from typing import Dict, Tuple, List
from datetime import datetime
from tqdm import tqdm
import http.client

BASE_URL = 'https://www.sec.gov'

def create_urls_df(cusip_df: pd.DataFrame,
                   dates_from_to:Tuple[str,str] = ('2023-01-01', '2024-01-01'),
                   user_email:str='sales@neo4j.com',
                   user_name='Neo4j') -> pd.DataFrame:
    
    print(f'Found {cusip_df.shape[0]:,} companies to pull filings for')
    start_date = datetime.strptime(dates_from_to[0], '%Y-%m-%d').date()
    end_date = datetime.strptime(dates_from_to[1], '%Y-%m-%d').date()

    urls_list = []

    counter = 0
    for ind, row in tqdm(cusip_df.iterrows()):
        #counter += 1
        #print(f'pulling 10k urls for cusip6: {row.cusip6}, {counter} of {map_df.shape[0]} cusips')
        urls = get_urls(row.cik, start_date, end_date, f'{user_name} {user_email}')
        #print(f'{row.cik}: {urls}')
        urls_list.append(urls)

    cusip_df['form10KUrls'] = urls_list
    return cusip_df[cusip_df.form10KUrls.map(len) > 0].explode(column='form10KUrls')


def get_urls(cik: str, start_date: datetime.date, end_date: datetime.date, user_agent: str):
    filing_accessors = get_filing_accessors(cik, start_date, end_date, user_agent)
    return [format_url(cik, f) for f in filing_accessors]


def get_filing_accessors(cik: str, start_date: datetime.date, end_date: datetime.date, user_agent: str) -> List[str]:
    history = get_filing_history(cik, user_agent)
    history_df = pd.DataFrame.from_dict(history['filings']['recent'])
    history_df.filingDate = pd.to_datetime(history_df.filingDate).dt.date
    filtered_df = history_df[(history_df.filingDate <= end_date) &
                             (history_df.filingDate >= start_date) &
                             (history_df.form == '10-K')]
    return filtered_df.accessionNumber.tolist()


def get_filing_history(cik: str, user_agent: str) -> Dict:
    url = f'https://data.sec.gov//submissions/CIK{int(cik):010d}.json'
    #print(f'Downloading filing history for cik: {cik}')
    conn = http.client.HTTPSConnection('www.sec.gov')
    conn.request('GET', url, headers={'User-Agent': user_agent})
    response = conn.getresponse()
    #print(response.status, response.reason)
    data = response.read()
    conn.close()

    if response.status == 200 and response.reason == 'OK':
        res = data.decode('utf-8')
        return json.loads(res)
    else:
        print(f'Download failed for cik: {cik} filings.')
    return dict()


def format_url(cik: str, filing_accessor: str):
    return BASE_URL + f'/Archives/edgar/data/{int(cik)}/{filing_accessor.replace("-", "")}/{filing_accessor}.txt'

# %%
ddf = map_df[:3].reset_index(drop=True)
create_urls_df(ddf)
# Out:
# Found 3 companies to pull filings for
# 3it [00:00,  3.29it/s]
#    cusip6      cik                              name  \
# 0  001055     4977                     {'AFLAC INC'}
# 2  001228  1514281  {'AG MORTGAGE INVESTMENT TRUST'}
#
#                                                   cusip  \
# 0  {'001055102', '001055952', '000105510', '001055902'}
# 2                                         {'001228501'}
#
#                                                                                    form10KUrls
# 0     https://www.sec.gov/Archives/edgar/data/4977/000000497723000055/0000004977-23-000055.txt
# 2  https://www.sec.gov/Archives/edgar/data/1514281/000151428123000020/0001514281-23-000020.txt

# %%
urls_df = create_urls_df(map_df)
urls_df
# Out:
# Found 4,648 companies to pull filings for
# 4648it [23:40,  3.27it/s]
#       cusip6      cik  \
# 0     001055     4977
# 2     001228  1514281
# 3     00123Q  1423689
# 4     00130H   874761
# 6     00164V  1514991
# ...      ...      ...
# 4624  Y2187A  1322439
# 4626  Y2573F   866374
# 4627  Y2685T  1326200
# 4632  Y41053  1679049
# 4647  Y95308  1631574
#
#                                                                                                    name  \
# 0                                                                                         {'AFLAC INC'}
# 2                                                                      {'AG MORTGAGE INVESTMENT TRUST'}
# 3                                                           {'AGNC INVT CORP', 'AGNC Investment Corp.'}
# 4                                                                                          {'AES CORP'}
# 6                                                            {'AMC NETWORKS INC', 'AMC NETWORKS INC A'}
# ...                                                                                                 ...
# 4624                                                                        {'EAGLE BULK SHIPPING INC'}
# 4626                                                                           {'Flex Ltd', 'FLEX LTD'}
# 4627  {'GENCO SHIPPING AND TRADING LIM', 'GENCO SHIPPING & TRADING LTD', 'GENCO SHIPPING  TRADING LTD'}
# 4632                                                                      {'INTERNATIONAL SEAWAYS INC'}
# 4647                                                                         {'WAVE LIFE SCIENCES LTD'}
#
#                                                      cusip  \
# 0     {'001055102', '001055952', '000105510', '001055902'}
# 2                                            {'001228501'}
# 3     {'00123q104', '00123Q104', '00123Q954', '00123Q904'}
# 4     {'00130H905', '00130H955', '00130H105', '00130h105'}
# 6                  {'00164V103', '00164V903', '00164V953'}
# ...                                                    ...
# 4624  {'y2187a150', 'Y2187A150', 'Y2187A900', 'Y2187A950'}
# 4626  {'y2573f102', 'Y2573F102', 'Y2573F902', 'Y2573F952'}
# 4627  {'Y2685T131', 'Y2685T901', 'Y2685T951', 'y2685t131'}
# 4632               {'Y41053952', 'Y41053102', 'Y41053902'}
# 4647                                         {'Y95308105'}
#
#                                                                                       form10KUrls
# 0        https://www.sec.gov/Archives/edgar/data/4977/000000497723000055/0000004977-23-000055.txt
# 2     https://www.sec.gov/Archives/edgar/data/1514281/000151428123000020/0001514281-23-000020.txt
# 3     https://www.sec.gov/Archives/edgar/data/1423689/000142368923000017/0001423689-23-000017.txt
# 4      https://www.sec.gov/Archives/edgar/data/874761/000087476123000010/0000874761-23-000010.txt
# 6     https://www.sec.gov/Archives/edgar/data/1514991/000151499123000009/0001514991-23-000009.txt
# ...                                                                                           ...
# 4624  https://www.sec.gov/Archives/edgar/data/1322439/000162828023007526/0001628280-23-007526.txt
# 4626   https://www.sec.gov/Archives/edgar/data/866374/000086637423000028/0000866374-23-000028.txt
# 4627  https://www.sec.gov/Archives/edgar/data/1326200/000155837023001781/0001558370-23-001781.txt
# 4632  https://www.sec.gov/Archives/edgar/data/1679049/000155837023002247/0001558370-23-002247.txt
# 4647  https://www.sec.gov/Archives/edgar/data/1631574/000095017023009319/0000950170-23-009319.txt
#
# [3365 rows x 5 columns]

# %%
urls_df.to_csv('f10k-urls-map.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 urls_df.to_csv('f10k-urls-map.csv', index=False)
#
# NameError: name 'urls_df' is not defined

# %% [markdown]
# ## Download, Parse, and Format 10k Forms

# %%
urls_df = pd.read_csv('f10k-urls-map.csv')
urls_df
# Out:
#       cusip6      cik  \
# 0     001055     4977
# 1     001228  1514281
# 2     00123Q  1423689
# 3     00130H   874761
# 4     00164V  1514991
# ...      ...      ...
# 3360  Y2187A  1322439
# 3361  Y2573F   866374
# 3362  Y2685T  1326200
# 3363  Y41053  1679049
# 3364  Y95308  1631574
#
#                                                                                                    name  \
# 0                                                                                         {'AFLAC INC'}
# 1                                                                      {'AG MORTGAGE INVESTMENT TRUST'}
# 2                                                           {'AGNC INVT CORP', 'AGNC Investment Corp.'}
# 3                                                                                          {'AES CORP'}
# 4                                                            {'AMC NETWORKS INC', 'AMC NETWORKS INC A'}
# ...                                                                                                 ...
# 3360                                                                        {'EAGLE BULK SHIPPING INC'}
# 3361                                                                           {'Flex Ltd', 'FLEX LTD'}
# 3362  {'GENCO SHIPPING AND TRADING LIM', 'GENCO SHIPPING & TRADING LTD', 'GENCO SHIPPING  TRADING LTD'}
# 3363                                                                      {'INTERNATIONAL SEAWAYS INC'}
# 3364                                                                         {'WAVE LIFE SCIENCES LTD'}
#
#                                                      cusip  \
# 0     {'001055102', '001055952', '000105510', '001055902'}
# 1                                            {'001228501'}
# 2     {'00123q104', '00123Q104', '00123Q954', '00123Q904'}
# 3     {'00130H905', '00130H955', '00130H105', '00130h105'}
# 4                  {'00164V103', '00164V903', '00164V953'}
# ...                                                    ...
# 3360  {'y2187a150', 'Y2187A150', 'Y2187A900', 'Y2187A950'}
# 3361  {'y2573f102', 'Y2573F102', 'Y2573F902', 'Y2573F952'}
# 3362  {'Y2685T131', 'Y2685T901', 'Y2685T951', 'y2685t131'}
# 3363               {'Y41053952', 'Y41053102', 'Y41053902'}
# 3364                                         {'Y95308105'}
#
#                                                                                       form10KUrls
# 0        https://www.sec.gov/Archives/edgar/data/4977/000000497723000055/0000004977-23-000055.txt
# 1     https://www.sec.gov/Archives/edgar/data/1514281/000151428123000020/0001514281-23-000020.txt
# 2     https://www.sec.gov/Archives/edgar/data/1423689/000142368923000017/0001423689-23-000017.txt
# 3      https://www.sec.gov/Archives/edgar/data/874761/000087476123000010/0000874761-23-000010.txt
# 4     https://www.sec.gov/Archives/edgar/data/1514991/000151499123000009/0001514991-23-000009.txt
# ...                                                                                           ...
# 3360  https://www.sec.gov/Archives/edgar/data/1322439/000162828023007526/0001628280-23-007526.txt
# 3361   https://www.sec.gov/Archives/edgar/data/866374/000086637423000028/0000866374-23-000028.txt
# 3362  https://www.sec.gov/Archives/edgar/data/1326200/000155837023001781/0001558370-23-001781.txt
# 3363  https://www.sec.gov/Archives/edgar/data/1679049/000155837023002247/0001558370-23-002247.txt
# 3364  https://www.sec.gov/Archives/edgar/data/1631574/000095017023009319/0000950170-23-009319.txt
#
# [3365 rows x 5 columns]

# %%
import re
import io
from bs4 import BeautifulSoup

def make_10k_jsons(url_df:pd.DataFrame,
                   temp_dir:str='data/form10k',
                   output_dir:str='data/form10k-clean',
                   user_email:str='sales@neo4j.com',
                   user_name='Neo4j') -> int:


    print(f'Found {url_df.shape[0]:,} companies to pull filings for')
    if not os.path.exists(temp_dir):
        os.makedirs(temp_dir)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    count = 0
    total = url_df.shape[0]
    print(f'=== Downloading {total:,} 10K filings ===')
    for ind, row in url_df.iterrows():
        count += 1
        print(f'--- Downloading {count:,} of {total:,} 10K filings for {row.name}')
        raw_file_path, file_id = download_filing(row.form10KUrls, f'{user_name} {user_email}', temp_dir)
        if len(raw_file_path) > 0:
            output_file_path = os.path.join(output_dir, file_id + '.json')
            try:
                load_parse_save(raw_file_path, output_file_path, row.cik, row.cusip6, row.form10KUrls, row['name'])
                os.remove(raw_file_path)
            except Exception as e:
                print(e)
    return 0


def download_filing(url: str, user_agent: str, temp_dir: str) -> tuple:
    conn = http.client.HTTPSConnection('www.sec.gov')
    conn.request('GET', url, headers={'User-Agent': user_agent})
    response = conn.getresponse()
    data = response.read()
    conn.close()

    if response.status == 200 and response.reason == 'OK':
        text = data.decode('utf-8')
        file = io.StringIO(text)
        contents = file.read()
        file.close()
        file_id = url[url.rindex('/') + 1:url.rindex('.')]
        file_path = os.path.join(temp_dir, 'raw_' + file_id + '.txt')
        with open(file_path, 'w') as file:
            file.write(contents)
        return file_path, file_id
    else:
        print('Download failed for form13 file.')
        print(response.status, response.reason)
        return '', ''


def extract_10_k(txt: str) -> str:
    # Regex to find <DOCUMENT> tags
    doc_start_pattern = re.compile(r'<DOCUMENT>')
    doc_end_pattern = re.compile(r'</DOCUMENT>')
    # Regex to find <TYPE> tag proceeding any characters, terminating at new line
    type_pattern = re.compile(r'<TYPE>[^\n]+')
    # Create 3 lists with the span idices for each regex

    # There are many <Document> Tags in this text file, each as specific exhibit like 10-K, EX-10.17 etc
    # First filter will give us document tag start <end> and document tag end's <start>
    # We will use this to later grab content in between these tags
    doc_start_is = [x.end() for x in doc_start_pattern.finditer(txt)]
    doc_end_is = [x.start() for x in doc_end_pattern.finditer(txt)]

    # Type filter is interesting, it looks for <TYPE> with Not flag as new line, ie terminare there, with + sign
    # to look for any char afterwards until new line \n. This will give us <TYPE> followed Section Name like '10-K'
    # Once we have this, it returns String Array, below line will with find content after <TYPE> ie, '10-K'
    # as section names
    doc_types = [x[len('<TYPE>'):] for x in type_pattern.findall(txt)]
    # Create a loop to go through each section type and save only the 10-K section in the dictionary
    # there is just one 10-K section
    for doc_type, doc_start, doc_end in zip(doc_types, doc_start_is, doc_end_is):
        if doc_type == '10-K':
            return txt[doc_start:doc_end]


# Extract text using position dataframe and beautiful soup
def beautify_text(txt: str) -> str:
    stg_txt = BeautifulSoup(txt, 'lxml')
    return stg_txt.get_text('\n')


def extract_text(row: pd.Series, txt: str):
    section_txt = txt[row.start:row.sectionEnd].replace('Error! Bookmark not defined.', '')
    return beautify_text(section_txt)


def extract_section_text(doc: str) -> Dict[str, str]:
    # Write the regex
    regex = re.compile(r'(>(Item|ITEM)(\s|&#160;|&nbsp;)(1A|1B|1\.|7A|7|8)\.{0,1})|(ITEM\s(1A|1B|1\.|7A|7|8))')
    # Use finditer to math the regex
    matches = regex.finditer(doc)
    # Write a for loop to print the matches
    # Create the dataframe
    item_df = pd.DataFrame([(x.group(), x.start(), x.end()) for x in matches])
    item_df.columns = ['item', 'start', 'end']
    item_df['item'] = item_df.item.str.lower()

    item_df.replace('&#160;', ' ', regex=True, inplace=True)
    item_df.replace('&nbsp;', ' ', regex=True, inplace=True)
    item_df.replace(' ', '', regex=True, inplace=True)
    item_df.replace('\.', '', regex=True, inplace=True)
    item_df.replace('>', '', regex=True, inplace=True)

    all_pos_df = item_df.sort_values('start', ascending=True).drop_duplicates(subset=['item'], keep='last').set_index(
        'item')
    # Add section end using start of next section
    all_pos_df['sectionEnd'] = all_pos_df.start.iloc[1:].tolist() + [len(doc)]
    # filter to just the sections we care about
    pos_df = all_pos_df.loc[['item1', 'item1a', 'item7', 'item7a'], :]
    res = dict()
    for i, row in pos_df.iterrows():
        res[i] = extract_text(row, doc)
    return res

def extract_first_name(x):
    return x[2:x.find("'", x.find("'") + 1)].upper()

def load_parse_save(input_file_path: str, output_file_path: str, cik: str, cusip6: str, url: str, name:str) -> None:
    with open(input_file_path, 'r') as file:
        raw_txt = file.read()
    print('Extracting 10-K')
    doc = extract_10_k(raw_txt)
    print('Parsing relevant sections')
    cleaned_json_txt = extract_section_text(doc)
    cleaned_json_txt['cik'] = cik
    cleaned_json_txt['cusip6'] = cusip6
    cleaned_json_txt['source'] = url[:url.rindex('.')] + '-index.htm'
    cleaned_json_txt['name'] = extract_first_name(name)
    print('Writing clean text to json')
    with open(output_file_path, 'w') as json_file:
        json.dump(cleaned_json_txt, json_file, indent=4)

# %%
url_samp_df = urls_df
make_10k_jsons(url_samp_df)
# Out:
# Found 3,365 companies to pull filings for
# === Downloading 3,365 10K filings ===
# --- Downloading 1 of 3,365 10K filings for 0
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 2 of 3,365 10K filings for 1
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3 of 3,365 10K filings for 2
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 4 of 3,365 10K filings for 3
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 5 of 3,365 10K filings for 4
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 6 of 3,365 10K filings for 5
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 7 of 3,365 10K filings for 6
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 8 of 3,365 10K filings for 7
# Extracting 10-K
# Parsing relevant sections
# "['item7a'] not in index"
# --- Downloading 9 of 3,365 10K filings for 8
# Extracting 10-K
# Parsing relevant sections
# "None of [Index(['item1', 'item1a', 'item7', 'item7a'], dtype='object', name='item')] are in the [index]"
# --- Downloading 10 of 3,365 10K filings for 9
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 11 of 3,365 10K filings for 10
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 12 of 3,365 10K filings for 11
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 13 of 3,365 10K filings for 12
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 14 of 3,365 10K filings for 13
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 15 of 3,365 10K filings for 14
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 16 of 3,365 10K filings for 15
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 17 of 3,365 10K filings for 16
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 18 of 3,365 10K filings for 17
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 19 of 3,365 10K filings for 18
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 20 of 3,365 10K filings for 19
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 21 of 3,365 10K filings for 20
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 22 of 3,365 10K filings for 21
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 23 of 3,365 10K filings for 22
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 24 of 3,365 10K filings for 23
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 25 of 3,365 10K filings for 24
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 26 of 3,365 10K filings for 25
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 27 of 3,365 10K filings for 26
# Extracting 10-K
# Parsing relevant sections
# "['item1', 'item1a', 'item7a'] not in index"
# --- Downloading 28 of 3,365 10K filings for 27
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 29 of 3,365 10K filings for 28
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 30 of 3,365 10K filings for 29
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 31 of 3,365 10K filings for 30
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 32 of 3,365 10K filings for 31
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 33 of 3,365 10K filings for 32
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 34 of 3,365 10K filings for 33
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 35 of 3,365 10K filings for 34
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 36 of 3,365 10K filings for 35
# Extracting 10-K
# Parsing relevant sections
# Length mismatch: Expected axis has 0 elements, new values have 3 elements
# --- Downloading 37 of 3,365 10K filings for 36
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 38 of 3,365 10K filings for 37
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 39 of 3,365 10K filings for 38
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 40 of 3,365 10K filings for 39
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 41 of 3,365 10K filings for 40
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 42 of 3,365 10K filings for 41
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 43 of 3,365 10K filings for 42
# Extracting 10-K
# Parsing relevant sections
# "['item1a', 'item7a'] not in index"
# --- Downloading 44 of 3,365 10K filings for 43
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 45 of 3,365 10K filings for 44
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 46 of 3,365 10K filings for 45
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 47 of 3,365 10K filings for 46
# Extracting 10-K
# Parsing relevant sections
# "['item1'] not in index"
# --- Downloading 48 of 3,365 10K filings for 47
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 49 of 3,365 10K filings for 48
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 50 of 3,365 10K filings for 49
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 51 of 3,365 10K filings for 50
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 52 of 3,365 10K filings for 51
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 53 of 3,365 10K filings for 52
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 54 of 3,365 10K filings for 53
# Extracting 10-K
# Parsing relevant sections
# "['item1a'] not in index"
# --- Downloading 55 of 3,365 10K filings for 54
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 56 of 3,365 10K filings for 55
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 57 of 3,365 10K filings for 56
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 58 of 3,365 10K filings for 57
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 59 of 3,365 10K filings for 58
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 60 of 3,365 10K filings for 59
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 61 of 3,365 10K filings for 60
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 62 of 3,365 10K filings for 61
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 63 of 3,365 10K filings for 62
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 64 of 3,365 10K filings for 63
# Extracting 10-K
# Parsing relevant sections
# "['item7a'] not in index"
# --- Downloading 65 of 3,365 10K filings for 64
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 66 of 3,365 10K filings for 65
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 67 of 3,365 10K filings for 66
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 68 of 3,365 10K filings for 67
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 69 of 3,365 10K filings for 68
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 237 of 3,365 10K filings for 236
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 238 of 3,365 10K filings for 237
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 239 of 3,365 10K filings for 238
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 240 of 3,365 10K filings for 239
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 241 of 3,365 10K filings for 240
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 242 of 3,365 10K filings for 241
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 243 of 3,365 10K filings for 242
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 244 of 3,365 10K filings for 243
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 245 of 3,365 10K filings for 244
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 246 of 3,365 10K filings for 245
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 247 of 3,365 10K filings for 246
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 248 of 3,365 10K filings for 247
# Extracting 10-K
# Parsing relevant sections
# Length mismatch: Expected axis has 0 elements, new values have 3 elements
# --- Downloading 249 of 3,365 10K filings for 248
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 250 of 3,365 10K filings for 249
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 251 of 3,365 10K filings for 250
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 252 of 3,365 10K filings for 251
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 253 of 3,365 10K filings for 252
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 254 of 3,365 10K filings for 253
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 255 of 3,365 10K filings for 254
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 256 of 3,365 10K filings for 255
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 257 of 3,365 10K filings for 256
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 258 of 3,365 10K filings for 257
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 259 of 3,365 10K filings for 258
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 260 of 3,365 10K filings for 259
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 261 of 3,365 10K filings for 260
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 262 of 3,365 10K filings for 261
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 263 of 3,365 10K filings for 262
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 264 of 3,365 10K filings for 263
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 265 of 3,365 10K filings for 264
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 266 of 3,365 10K filings for 265
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 267 of 3,365 10K filings for 266
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 268 of 3,365 10K filings for 267
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 269 of 3,365 10K filings for 268
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 270 of 3,365 10K filings for 269
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 271 of 3,365 10K filings for 270
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 272 of 3,365 10K filings for 271
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 273 of 3,365 10K filings for 272
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 274 of 3,365 10K filings for 273
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 275 of 3,365 10K filings for 274
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 276 of 3,365 10K filings for 275
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 277 of 3,365 10K filings for 276
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 278 of 3,365 10K filings for 277
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 279 of 3,365 10K filings for 278
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 280 of 3,365 10K filings for 279
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 281 of 3,365 10K filings for 280
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 282 of 3,365 10K filings for 281
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 283 of 3,365 10K filings for 282
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 284 of 3,365 10K filings for 283
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 285 of 3,365 10K filings for 284
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 286 of 3,365 10K filings for 285
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 287 of 3,365 10K filings for 286
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 288 of 3,365 10K filings for 287
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 289 of 3,365 10K filings for 288
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 290 of 3,365 10K filings for 289
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 291 of 3,365 10K filings for 290
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 292 of 3,365 10K filings for 291
# Extracting 10-K
# Parsing relevant sections
# "['item1'] not in index"
# --- Downloading 293 of 3,365 10K filings for 292
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 294 of 3,365 10K filings for 293
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 295 of 3,365 10K filings for 294
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 296 of 3,365 10K filings for 295
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 297 of 3,365 10K filings for 296
# Extracting 10-K
# Parsing relevant sections
# "['item7a'] not in index"
# --- Downloading 298 of 3,365 10K filings for 297
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 299 of 3,365 10K filings for 298
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 300 of 3,365 10K filings for 299
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 301 of 3,365 10K filings for 300
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 302 of 3,365 10K filings for 301
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 303 of 3,365 10K filings for 302
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 304 of 3,365 10K filings for 303
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 305 of 3,365 10K filings for 304
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 306 of 3,365 10K filings for 305
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 307 of 3,365 10K filings for 306
# Extracting 10-K
# Parsing relevant sections
# "['item7', 'item7a'] not in index"
# --- Downloading 308 of 3,365 10K filings for 307
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 309 of 3,365 10K filings for 308
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 310 of 3,365 10K filings for 309
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 311 of 3,365 10K filings for 310
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 312 of 3,365 10K filings for 311
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 313 of 3,365 10K filings for 312
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 314 of 3,365 10K filings for 313
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 315 of 3,365 10K filings for 314
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 316 of 3,365 10K filings for 315
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 317 of 3,365 10K filings for 316
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 318 of 3,365 10K filings for 317
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 319 of 3,365 10K filings for 318
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 320 of 3,365 10K filings for 319
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 321 of 3,365 10K filings for 320
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 322 of 3,365 10K filings for 321
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 323 of 3,365 10K filings for 322
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 324 of 3,365 10K filings for 323
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 325 of 3,365 10K filings for 324
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 326 of 3,365 10K filings for 325
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 327 of 3,365 10K filings for 326
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 328 of 3,365 10K filings for 327
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 329 of 3,365 10K filings for 328
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 330 of 3,365 10K filings for 329
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 331 of 3,365 10K filings for 330
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 332 of 3,365 10K filings for 331
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 333 of 3,365 10K filings for 332
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 334 of 3,365 10K filings for 333
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 335 of 3,365 10K filings for 334
# Extracting 10-K
# Parsing relevant sections
# "['item1'] not in index"
# --- Downloading 336 of 3,365 10K filings for 335
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 337 of 3,365 10K filings for 336
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 338 of 3,365 10K filings for 337
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 339 of 3,365 10K filings for 338
# Extracting 10-K
# Parsing relevant sections
# "['item7a'] not in index"
# --- Downloading 340 of 3,365 10K filings for 339
# Extracting 10-K
# Parsing relevant sections
# Length mismatch: Expected axis has 0 elements, new values have 3 elements
# --- Downloading 341 of 3,365 10K filings for 340
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 342 of 3,365 10K filings for 341
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 343 of 3,365 10K filings for 342
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 344 of 3,365 10K filings for 343
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 345 of 3,365 10K filings for 344
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 346 of 3,365 10K filings for 345
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 347 of 3,365 10K filings for 346
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 348 of 3,365 10K filings for 347
# Extracting 10-K
# Parsing relevant sections
# "['item1a'] not in index"
# --- Downloading 349 of 3,365 10K filings for 348
# Extracting 10-K
# Parsing relevant sections
# "None of [Index(['item1', 'item1a', 'item7', 'item7a'], dtype='object', name='item')] are in the [index]"
# --- Downloading 350 of 3,365 10K filings for 349
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 351 of 3,365 10K filings for 350
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 352 of 3,365 10K filings for 351
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 353 of 3,365 10K filings for 352
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 354 of 3,365 10K filings for 353
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 355 of 3,365 10K filings for 354
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 356 of 3,365 10K filings for 355
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 357 of 3,365 10K filings for 356
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 358 of 3,365 10K filings for 357
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 359 of 3,365 10K filings for 358
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 360 of 3,365 10K filings for 359
# Extracting 10-K
# Parsing relevant sections
# "None of [Index(['item1', 'item1a', 'item7', 'item7a'], dtype='object', name='item')] are in the [index]"
# --- Downloading 361 of 3,365 10K filings for 360
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 362 of 3,365 10K filings for 361
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 363 of 3,365 10K filings for 362
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 364 of 3,365 10K filings for 363
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 365 of 3,365 10K filings for 364
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 366 of 3,365 10K filings for 365
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 367 of 3,365 10K filings for 366
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 368 of 3,365 10K filings for 367
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 369 of 3,365 10K filings for 368
# Extracting 10-K
# Parsing relevant sections
# "['item1a'] not in index"
# --- Downloading 370 of 3,365 10K filings for 369
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 371 of 3,365 10K filings for 370
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 372 of 3,365 10K filings for 371
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 373 of 3,365 10K filings for 372
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 374 of 3,365 10K filings for 373
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 375 of 3,365 10K filings for 374
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 376 of 3,365 10K filings for 375
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 377 of 3,365 10K filings for 376
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 378 of 3,365 10K filings for 377
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 379 of 3,365 10K filings for 378
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 380 of 3,365 10K filings for 379
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 381 of 3,365 10K filings for 380
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 382 of 3,365 10K filings for 381
# Extracting 10-K
# Parsing relevant sections
# "None of [Index(['item1', 'item1a', 'item7', 'item7a'], dtype='object', name='item')] are in the [index]"
# --- Downloading 383 of 3,365 10K filings for 382
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 384 of 3,365 10K filings for 383
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 385 of 3,365 10K filings for 384
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 386 of 3,365 10K filings for 385
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 387 of 3,365 10K filings for 386
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 388 of 3,365 10K filings for 387
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 389 of 3,365 10K filings for 388
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 390 of 3,365 10K filings for 389
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 391 of 3,365 10K filings for 390
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,297 of 3,365 10K filings for 3296
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,298 of 3,365 10K filings for 3297
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,299 of 3,365 10K filings for 3298
# Extracting 10-K
# Parsing relevant sections
# "['item7a'] not in index"
# --- Downloading 3,300 of 3,365 10K filings for 3299
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,301 of 3,365 10K filings for 3300
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,302 of 3,365 10K filings for 3301
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,303 of 3,365 10K filings for 3302
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,304 of 3,365 10K filings for 3303
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,305 of 3,365 10K filings for 3304
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,306 of 3,365 10K filings for 3305
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,307 of 3,365 10K filings for 3306
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,308 of 3,365 10K filings for 3307
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,309 of 3,365 10K filings for 3308
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,310 of 3,365 10K filings for 3309
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,311 of 3,365 10K filings for 3310
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,312 of 3,365 10K filings for 3311
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,313 of 3,365 10K filings for 3312
# Extracting 10-K
# Parsing relevant sections
# "['item1', 'item7', 'item7a'] not in index"
# --- Downloading 3,314 of 3,365 10K filings for 3313
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,315 of 3,365 10K filings for 3314
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,316 of 3,365 10K filings for 3315
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,317 of 3,365 10K filings for 3316
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,318 of 3,365 10K filings for 3317
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,319 of 3,365 10K filings for 3318
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,320 of 3,365 10K filings for 3319
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,321 of 3,365 10K filings for 3320
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,322 of 3,365 10K filings for 3321
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,323 of 3,365 10K filings for 3322
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,324 of 3,365 10K filings for 3323
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,325 of 3,365 10K filings for 3324
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,326 of 3,365 10K filings for 3325
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,327 of 3,365 10K filings for 3326
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,328 of 3,365 10K filings for 3327
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,329 of 3,365 10K filings for 3328
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,330 of 3,365 10K filings for 3329
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,331 of 3,365 10K filings for 3330
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,332 of 3,365 10K filings for 3331
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,333 of 3,365 10K filings for 3332
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,334 of 3,365 10K filings for 3333
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,335 of 3,365 10K filings for 3334
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,336 of 3,365 10K filings for 3335
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,337 of 3,365 10K filings for 3336
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,338 of 3,365 10K filings for 3337
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,339 of 3,365 10K filings for 3338
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,340 of 3,365 10K filings for 3339
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,341 of 3,365 10K filings for 3340
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,342 of 3,365 10K filings for 3341
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,343 of 3,365 10K filings for 3342
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,344 of 3,365 10K filings for 3343
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,345 of 3,365 10K filings for 3344
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,346 of 3,365 10K filings for 3345
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,347 of 3,365 10K filings for 3346
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,348 of 3,365 10K filings for 3347
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,349 of 3,365 10K filings for 3348
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,350 of 3,365 10K filings for 3349
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,351 of 3,365 10K filings for 3350
# Extracting 10-K
# Parsing relevant sections
# "['item1a', 'item7', 'item7a'] not in index"
# --- Downloading 3,352 of 3,365 10K filings for 3351
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,353 of 3,365 10K filings for 3352
# Extracting 10-K
# Parsing relevant sections
# "['item1'] not in index"
# --- Downloading 3,354 of 3,365 10K filings for 3353
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,355 of 3,365 10K filings for 3354
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,356 of 3,365 10K filings for 3355
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,357 of 3,365 10K filings for 3356
# Extracting 10-K
# Parsing relevant sections
# "['item1'] not in index"
# --- Downloading 3,358 of 3,365 10K filings for 3357
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,359 of 3,365 10K filings for 3358
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,360 of 3,365 10K filings for 3359
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,361 of 3,365 10K filings for 3360
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,362 of 3,365 10K filings for 3361
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,363 of 3,365 10K filings for 3362
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,364 of 3,365 10K filings for 3363
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# --- Downloading 3,365 of 3,365 10K filings for 3364
# Extracting 10-K
# Parsing relevant sections
# Writing clean text to json
# 0
